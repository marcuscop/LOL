# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import random
df = pd.read_csv('DATA/matches2020.csv')
df
# Out:
#       Unnamed: 0                 gameid league        blueteam  \
# 0              0  ESPORTSTMNT03/1241318  KeSPA  SANDBOX Gaming
# 1              1  ESPORTSTMNT03/1241322  KeSPA              T1
# 2              2  ESPORTSTMNT03/1241324  KeSPA              T1
# 3              3  ESPORTSTMNT03/1241328  KeSPA              T1
# 4              4  ESPORTSTMNT03/1241386  KeSPA             DRX
# ...          ...                    ...    ...             ...
# 5607        5607  ESPORTSTMNT03/1433741    LCS        FlyQuest
# 5608        5608  ESPORTSTMNT03/1433748    LCS        FlyQuest
# 5609        5609  ESPORTSTMNT03/1433749    LCS    Team SoloMid
# 5610        5610  ESPORTSTMNT03/1433751    LCS        FlyQuest
# 5611        5611  ESPORTSTMNT03/1433752    LCS    Team SoloMid
#
#              redteam      bluetop bluejungle      bluemid      blueadc  \
# 0                 T1       Rumble      Elise       Qiyana  MissFortune
# 1     SANDBOX Gaming        Jayce   JarvanIV      Orianna  MissFortune
# 2     SANDBOX Gaming     Renekton     RekSai  Mordekaiser        Xayah
# 3     SANDBOX Gaming     Pantheon      Elise     Nautilus        Xayah
# 4     Afreeca Freecs  Mordekaiser   JarvanIV         Ryze        Xayah
# ...              ...          ...        ...          ...          ...
# 5607    Team SoloMid         Ornn     Graves       Viktor      Caitlyn
# 5608    Team SoloMid         Ornn     Graves         Azir      Caitlyn
# 5609        FlyQuest        Jayce       Sett  TwistedFate         Ashe
# 5610    Team SoloMid         Ornn   Volibear         Azir      Caitlyn
# 5611        FlyQuest      Camille     Graves  TwistedFate        Senna
#
#      bluesupport     redtop redjungle       redmid       redadc redsupport  \
# 0       Nautilus     Aatrox    Gragas  Mordekaiser        Xayah      Rakan
# 1       Nautilus     Aatrox     Elise       Qiyana        Varus  TahmKench
# 2          Rakan     Aatrox   Sejuani         Azir  MissFortune   Nautilus
# 3          Rakan      Quinn      Olaf      Orianna  MissFortune      Leona
# 4          Rakan   Renekton     Elise       Velkoz        Varus      Braum
# ...          ...        ...       ...          ...          ...        ...
# 5607         Lux    Camille      Sett       Zilean         Ashe      Karma
# 5608    Pantheon        Jax      Sett  TwistedFate         Ashe       Bard
# 5609        Bard  Gangplank   Hecarim      Orianna        Senna   Nautilus
# 5610    Pantheon      Jayce      Sett       Syndra         Ashe    Morgana
# 5611       Rakan  Gangplank      Sett      Orianna         Ashe      Leona
#
#       result
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 5607       0
# 5608       0
# 5609       0
# 5610       1
# 5611       1
#
# [5612 rows x 16 columns]

# %%
df.dtypes
df = df.drop(columns=["Unnamed: 0","gameid","league","blueteam","redteam"])
df.count()
# Out:
# bluetop        5612
# bluejungle     5612
# bluemid        5612
# blueadc        5612
# bluesupport    5612
# redtop         5612
# redjungle      5612
# redmid         5612
# redadc         5612
# redsupport     5612
# result         5612
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#           bluetop bluejungle      bluemid      blueadc bluesupport     redtop  \
# 0          Rumble      Elise       Qiyana  MissFortune    Nautilus     Aatrox
# 1           Jayce   JarvanIV      Orianna  MissFortune    Nautilus     Aatrox
# 2        Renekton     RekSai  Mordekaiser        Xayah       Rakan     Aatrox
# 3        Pantheon      Elise     Nautilus        Xayah       Rakan      Quinn
# 4     Mordekaiser   JarvanIV         Ryze        Xayah       Rakan   Renekton
# ...           ...        ...          ...          ...         ...        ...
# 5607         Ornn     Graves       Viktor      Caitlyn         Lux    Camille
# 5608         Ornn     Graves         Azir      Caitlyn    Pantheon        Jax
# 5609        Jayce       Sett  TwistedFate         Ashe        Bard  Gangplank
# 5610         Ornn   Volibear         Azir      Caitlyn    Pantheon      Jayce
# 5611      Camille     Graves  TwistedFate        Senna       Rakan  Gangplank
#
#      redjungle       redmid       redadc redsupport  result
# 0       Gragas  Mordekaiser        Xayah      Rakan       1
# 1        Elise       Qiyana        Varus  TahmKench       0
# 2      Sejuani         Azir  MissFortune   Nautilus       1
# 3         Olaf      Orianna  MissFortune      Leona       0
# 4        Elise       Velkoz        Varus      Braum       0
# ...        ...          ...          ...        ...     ...
# 5607      Sett       Zilean         Ashe      Karma       0
# 5608      Sett  TwistedFate         Ashe       Bard       0
# 5609   Hecarim      Orianna        Senna   Nautilus       0
# 5610      Sett       Syndra         Ashe    Morgana       1
# 5611      Sett      Orianna         Ashe      Leona       1
#
# [5612 rows x 11 columns]

# %% [markdown]
# ### Load Hashmap

# %%
df_c = pd.read_csv('DATA/champion_stats.csv')

champkeys = {}

for i in range(len(df_c["key"])):
    champkeys[df_c["key"][i]] = df_c["id"][i]

champkeys
# Out:
# {266: 'Aatrox',
#  103: 'Ahri',
#  84: 'Akali',
#  12: 'Alistar',
#  32: 'Amumu',
#  34: 'Anivia',
#  1: 'Annie',
#  523: 'Aphelios',
#  22: 'Ashe',
#  136: 'AurelionSol',
#  268: 'Azir',
#  432: 'Bard',
#  53: 'Blitzcrank',
#  63: 'Brand',
#  201: 'Braum',
#  51: 'Caitlyn',
#  164: 'Camille',
#  69: 'Cassiopeia',
#  31: 'Chogath',
#  42: 'Corki',
#  122: 'Darius',
#  131: 'Diana',
#  119: 'Draven',
#  36: 'DrMundo',
#  245: 'Ekko',
#  60: 'Elise',
#  28: 'Evelynn',
#  81: 'Ezreal',
#  9: 'Fiddlesticks',
#  114: 'Fiora',
#  105: 'Fizz',
#  3: 'Galio',
#  41: 'Gangplank',
#  86: 'Garen',
#  150: 'Gnar',
#  79: 'Gragas',
#  104: 'Graves',
#  120: 'Hecarim',
#  74: 'Heimerdinger',
#  420: 'Illaoi',
#  39: 'Irelia',
#  427: 'Ivern',
#  40: 'Janna',
#  59: 'JarvanIV',
#  24: 'Jax',
#  126: 'Jayce',
#  202: 'Jhin',
#  222: 'Jinx',
#  145: 'Kaisa',
#  429: 'Kalista',
#  43: 'Karma',
#  30: 'Karthus',
#  38: 'Kassadin',
#  55: 'Katarina',
#  10: 'Kayle',
#  141: 'Kayn',
#  85: 'Kennen',
#  121: 'Khazix',
#  203: 'Kindred',
#  240: 'Kled',
#  96: 'KogMaw',
#  7: 'Leblanc',
#  64: 'LeeSin',
#  89: 'Leona',
#  876: 'Lillia',
#  127: 'Lissandra',
#  236: 'Lucian',
#  117: 'Lulu',
#  99: 'Lux',
#  54: 'Malphite',
#  90: 'Malzahar',
#  57: 'Maokai',
#  11: 'MasterYi',
#  21: 'MissFortune',
#  62: 'MonkeyKing',
#  82: 'Mordekaiser',
#  25: 'Morgana',
#  267: 'Nami',
#  75: 'Nasus',
#  111: 'Nautilus',
#  518: 'Neeko',
#  76: 'Nidalee',
#  56: 'Nocturne',
#  20: 'Nunu',
#  2: 'Olaf',
#  61: 'Orianna',
#  516: 'Ornn',
#  80: 'Pantheon',
#  78: 'Poppy',
#  555: 'Pyke',
#  246: 'Qiyana',
#  133: 'Quinn',
#  497: 'Rakan',
#  33: 'Rammus',
#  421: 'RekSai',
#  58: 'Renekton',
#  107: 'Rengar',
#  92: 'Riven',
#  68: 'Rumble',
#  13: 'Ryze',
#  113: 'Sejuani',
#  235: 'Senna',
#  875: 'Sett',
#  35: 'Shaco',
#  98: 'Shen',
#  102: 'Shyvana',
#  27: 'Singed',
#  14: 'Sion',
#  15: 'Sivir',
#  72: 'Skarner',
#  37: 'Sona',
#  16: 'Soraka',
#  50: 'Swain',
#  517: 'Sylas',
#  134: 'Syndra',
#  223: 'TahmKench',
#  163: 'Taliyah',
#  91: 'Talon',
#  44: 'Taric',
#  17: 'Teemo',
#  412: 'Thresh',
#  18: 'Tristana',
#  48: 'Trundle',
#  23: 'Tryndamere',
#  4: 'TwistedFate',
#  29: 'Twitch',
#  77: 'Udyr',
#  6: 'Urgot',
#  110: 'Varus',
#  67: 'Vayne',
#  45: 'Veigar',
#  161: 'Velkoz',
#  254: 'Vi',
#  112: 'Viktor',
#  8: 'Vladimir',
#  106: 'Volibear',
#  19: 'Warwick',
#  498: 'Xayah',
#  101: 'Xerath',
#  5: 'XinZhao',
#  157: 'Yasuo',
#  777: 'Yone',
#  83: 'Yorick',
#  350: 'Yuumi',
#  154: 'Zac',
#  238: 'Zed',
#  115: 'Ziggs',
#  26: 'Zilean',
#  142: 'Zoe',
#  143: 'Zyra'}

# %% [markdown]
# ### Ranked Data

# %%
print(md['participants'][0])
# Out:
# [{'participantId': 1, 'teamId': 100, 'championId': 7, 'spell1Id': 1, 'spell2Id': 4, 'stats': {'participantId': 1, 'win': False, 'item0': 2033, 'item1': 3285, 'item2': 3108, 'item3': 1082, 'item4': 3020, 'item5': 2055, 'item6': 3364, 'kills': 3, 'deaths': 6, 'assists': 3, 'largestKillingSpree': 2, 'largestMultiKill': 1, 'killingSprees': 1, 'longestTimeSpentLiving': 564, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 71369, 'magicDamageDealt': 56332, 'physicalDamageDealt': 13037, 'trueDamageDealt': 1999, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 10844, 'magicDamageDealtToChampions': 8926, 'physicalDamageDealtToChampions': 1918, 'trueDamageDealtToChampions': 0, 'totalHeal': 4006, 'totalUnitsHealed': 1, 'damageSelfMitigated': 6742, 'damageDealtToObjectives': 1055, 'damageDealtToTurrets': 1008, 'visionScore': 14, 'timeCCingOthers': 12, 'totalDamageTaken': 17255, 'magicalDamageTaken': 5282, 'physicalDamageTaken': 11203, 'trueDamageTaken': 770, 'goldEarned': 6844, 'goldSpent': 6710, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 133, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 19, 'champLevel': 12, 'visionWardsBoughtInGame': 3, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 6, 'wardsKilled': 1, 'firstBloodKill': True, 'firstBloodAssist': False, 'firstTowerKill': False, 'firstTowerAssist': False, 'firstInhibitorKill': False, 'firstInhibitorAssist': False, 'combatPlayerScore': 0, 'objectivePlayerScore': 0, 'totalPlayerScore': 0, 'totalScoreRank': 0, 'playerScore0': 0, 'playerScore1': 0, 'playerScore2': 0, 'playerScore3': 0, 'playerScore4': 0, 'playerScore5': 0, 'playerScore6': 0, 'playerScore7': 0, 'playerScore8': 0, 'playerScore9': 0, 'perk0': 8112, 'perk0Var1': 735, 'perk0Var2': 0, 'perk0Var3': 0, 'perk1': 8139, 'perk1Var1': 664, 'perk1Var2': 0, 'perk1Var3': 0, 'perk2': 8138, 'perk2Var1': 12, 'perk2Var2': 0, 'perk2Var3': 0, 'perk3': 8135, 'perk3Var1': 1652, 'perk3Var2': 3, 'perk3Var3': 0, 'perk4': 8316, 'perk4Var1': 2016, 'perk4Var2': 0, 'perk4Var3': 0, 'perk5': 8352, 'perk5Var1': 288, 'perk5Var2': 1854, 'perk5Var3': 984, 'perkPrimaryStyle': 8100, 'perkSubStyle': 8300, 'statPerk0': 5005, 'statPerk1': 5008, 'statPerk2': 5003}, 'timeline': {'participantId': 1, 'creepsPerMinDeltas': {'10-20': 6.199999999999999, '0-10': 6.1}, 'xpPerMinDeltas': {'10-20': 473.5, '0-10': 386.6}, 'goldPerMinDeltas': {'10-20': 277, '0-10': 315.6}, 'damageTakenPerMinDeltas': {'10-20': 906, '0-10': 473.79999999999995}, 'role': 'DUO_CARRY', 'lane': 'MIDDLE'}}, {'participantId': 2, 'teamId': 100, 'championId': 350, 'spell1Id': 3, 'spell2Id': 7, 'stats': {'participantId': 2, 'win': False, 'item0': 3114, 'item1': 3853, 'item2': 0, 'item3': 1004, 'item4': 3041, 'item5': 3174, 'item6': 3364, 'kills': 0, 'deaths': 6, 'assists': 10, 'largestKillingSpree': 0, 'largestMultiKill': 0, 'killingSprees': 0, 'longestTimeSpentLiving': 559, 'doubleKills': 0, 'tripleKills': 0, 'quadraKills': 0, 'pentaKills': 0, 'unrealKills': 0, 'totalDamageDealt': 11569, 'magicDamageDealt': 8968, 'physicalDamageDealt': 2601, 'trueDamageDealt': 0, 'largestCriticalStrike': 0, 'totalDamageDealtToChampions': 7095, 'magicDamageDealtToChampions': 6069, 'physicalDamageDealtToChampions': 1025, 'trueDamageDealtToChampions': 0, 'totalHeal': 11758, 'totalUnitsHealed': 5, 'damageSelfMitigated': 5371, 'damageDealtToObjectives': 427, 'damageDealtToTurrets': 427, 'visionScore': 34, 'timeCCingOthers': 8, 'totalDamageTaken': 9994, 'magicalDamageTaken': 2293, 'physicalDamageTaken': 7163, 'trueDamageTaken': 537, 'goldEarned': 5205, 'goldSpent': 5212, 'turretKills': 0, 'inhibitorKills': 0, 'totalMinionsKilled': 2, 'neutralMinionsKilled': 0, 'neutralMinionsKilledTeamJungle': 0, 'neutralMinionsKilledEnemyJungle': 0, 'totalTimeCrowdControlDealt': 38, 'champLevel': 10, 'visionWardsBoughtInGame': 4, 'sightWardsBoughtInGame': 0, 'wardsPlaced': 17 ...

# %%
md = pd.read_csv('DATA/match_data_version1.csv')
md
# Out:
#         Unnamed: 0  gameCreation  gameDuration        gameId gameMode  \
# 0                0  1.585155e+12        1323.0  4.247263e+09  CLASSIC
# 1                1  1.585152e+12        1317.0  4.247156e+09  CLASSIC
# 2                2  1.585059e+12         932.0  4.243963e+09  CLASSIC
# 3                3  1.584978e+12        2098.0  4.241678e+09  CLASSIC
# 4                4  1.584973e+12        2344.0  4.241539e+09  CLASSIC
# ...            ...           ...           ...           ...      ...
# 108824           0  1.579163e+12        1029.0  4.088497e+09      URF
# 108825           0  1.580823e+12        1544.0  4.130964e+09  CLASSIC
# 108826           0  1.580382e+12        2090.0  4.119954e+09  CLASSIC
# 108827           0  1.580805e+12        1382.0  4.130440e+09      URF
# 108828           0  1.584505e+12        1432.0  4.225861e+09     ARAM
#
#             gameType    gameVersion  mapId  \
# 0       MATCHED_GAME  10.6.314.4405   11.0
# 1       MATCHED_GAME  10.6.314.4405   11.0
# 2       MATCHED_GAME  10.6.313.8894   11.0
# 3       MATCHED_GAME  10.6.313.8894   11.0
# 4       MATCHED_GAME  10.6.313.8894   11.0
# ...              ...            ...    ...
# 108824  MATCHED_GAME  10.1.303.9385   11.0
# 108825  MATCHED_GAME  10.2.305.4739   11.0
# 108826  MATCHED_GAME  10.2.305.4739   11.0
# 108827  MATCHED_GAME  10.2.305.4739   11.0
# 108828  MATCHED_GAME  10.6.313.2784   12.0
#
#                                     participantIdentities  \
# 0       [{'participantId': 1, 'player': {'platformId':...
# 1       [{'participantId': 1, 'player': {'platformId':...
# 2       [{'participantId': 1, 'player': {'platformId':...
# 3       [{'participantId': 1, 'player': {'platformId':...
# 4       [{'participantId': 1, 'player': {'platformId':...
# ...                                                   ...
# 108824  [{'participantId': 1, 'player': {'platformId':...
# 108825  [{'participantId': 1, 'player': {'platformId':...
# 108826  [{'participantId': 1, 'player': {'platformId':...
# 108827  [{'participantId': 1, 'player': {'platformId':...
# 108828  [{'participantId': 1, 'player': {'platformId':...
#
#                                              participants platformId  queueId  \
# 0       [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 1       [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 2       [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 3       [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 4       [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# ...                                                   ...        ...      ...
# 108824  [{'participantId': 1, 'teamId': 100, 'champion...         KR    900.0
# 108825  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 108826  [{'participantId': 1, 'teamId': 100, 'champion...         KR    420.0
# 108827  [{'participantId': 1, 'teamId': 100, 'champion...         KR    900.0
# 108828  [{'participantId': 1, 'teamId': 100, 'champion...         KR    450.0
#
#         seasonId  status.message  status.status_code
# 0           13.0             NaN                 NaN
# 1           13.0             NaN                 NaN
# 2           13.0             NaN                 NaN
# 3           13.0             NaN                 NaN
# 4           13.0             NaN                 NaN
# ...          ...             ...                 ...
# 108824      13.0             NaN                 NaN
# 108825      13.0             NaN                 NaN
# 108826      13.0             NaN                 NaN
# 108827      13.0             NaN                 NaN
# 108828      13.0             NaN                 NaN
#
# [108829 rows x 15 columns]

# %%
#print(md["participants"][0])

df_r = df.copy()
for i in range(len(md["gameMode"])):
    if(i%1000 == 0):
        print(i)
        
    if(md["gameMode"][i] == "CLASSIC"):
        
        # get the champions
        next_index = len(df['bluetop'])
        #print(next_index)
        string = md["participants"][i]
        loc = 0
        loc_p = 0
        loc_l = 0
        loc_w = 0
        
        bt_f = False
        bm_f = False
        bs_f = False
        bb_f = False
        bj_f = False
        
        rt_f = False
        rm_f = False
        rs_f = False
        rb_f = False
        rj_f = False
        
        for p in range(10):
            
            #get win
            if(p == 0):
                loc_w = string.find("win", (loc_w+1), len(string)-1)
                won = string[loc_w+6:loc_w+10]
                bwin = 0
                if(won.lower() == "true"):
                    bwin = 1
            
            #get champ id
            loc = string.find("championId", (loc+1), len(string)-1)
            space = string.find(",", (loc+13), len(string)-1)
            try:
                champid = int(string[loc+13:space])
            except ValueError as err:
                print("err")
            
            #get position
            loc_p = string.find("role", (loc_p+1), len(string)-1)
            support = string[loc_p+12:loc_p+19]
            loc_l = string.find("lane", (loc_l+1), len(string)-1)
            lane = string[loc_l+8]
            #print(lane)
            #champid = string[loc+13:space]
            
            if(p < 5 and support == "SUPPORT"):
                df.at[next_index, "bluesupport"] = champkeys[champid]
                #print("bS: ", champkeys[champid])
                
            elif(p < 5 and support != "SUPPORT"):
                if(p < 5 and lane == "B"):
                    df.at[next_index, "blueadc"] = champkeys[champid]
                    #print("bB: ", champkeys[champid])
                elif(p < 5 and lane == "J"):
                    df.at[next_index, "bluejungle"] = champkeys[champid]
                    #print("bJ: ", champkeys[champid])
                elif(p < 5 and lane == "M"):
                    df.at[next_index, "bluemid"] = champkeys[champid]
                    #print("bM: ", champkeys[champid])
                elif(p < 5 and lane == "T"):
                    df.at[next_index, "bluetop"] = champkeys[champid]
                    #print("bT: ", champkeys[champid])
                
            if(p >= 5 and support == "SUPPORT"):
                df.at[next_index, "redsupport"] = champkeys[champid]
                #print("rS: ", champkeys[champid])
                
            elif(p >= 5 and support != "SUPPORT"):
                if(p >= 5 and lane == "B"):
                    df.at[next_index, "redadc"] = champkeys[champid]
                    #print("rB: ", champkeys[champid])
                elif(p >= 5 and lane == "J"):
                    df.at[next_index, "redjungle"] = champkeys[champid]
                    #print("rJ: ", champkeys[champid])
                elif(p >= 5 and lane == "M"):
                    df.at[next_index, "redmid"] = champkeys[champid]
                    #print("rM: ", champkeys[champid])
                elif(p >= 5 and lane == "T"):
                    df.at[next_index, "redtop"] = champkeys[champid]
                    #print("rT: ", champkeys[champid])
                
            #print(next_index)
                
            if(p == 0):
                df.at[next_index, "result"] = bwin
                #print("result: ", bwin)
            
        
        #break
            
            
    
#print(md["participants"][0])
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# err
# 75000
# 76000
# 77000
# 78000
# err
# 79000
# 80000
# err
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# err
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# err
# 103000
# 104000
# 105000
# 106000
# err
# 107000
# 108000

# %%
print(len(df["bluetop"]))
df = df.dropna()
print(len(df["bluetop"]))
df
# Out:
# 98469
# 40432
#            bluetop bluejungle      bluemid      blueadc bluesupport  \
# 0           Rumble      Elise       Qiyana  MissFortune    Nautilus
# 1            Jayce   JarvanIV      Orianna  MissFortune    Nautilus
# 2         Renekton     RekSai  Mordekaiser        Xayah       Rakan
# 3         Pantheon      Elise     Nautilus        Xayah       Rakan
# 4      Mordekaiser   JarvanIV         Ryze        Xayah       Rakan
# ...            ...        ...          ...          ...         ...
# 98452       Darius   JarvanIV     Katarina     Vladimir       Yuumi
# 98459         Sett     RekSai     Katarina        Xayah        Pyke
# 98462        Garen     LeeSin      Leblanc     Aphelios        Bard
# 98463     Kassadin     LeeSin      Leblanc       Ezreal       Leona
# 98468       Soraka   JarvanIV       Qiyana  MissFortune        Pyke
#
#             redtop redjungle       redmid       redadc redsupport  result
# 0           Aatrox    Gragas  Mordekaiser        Xayah      Rakan     1.0
# 1           Aatrox     Elise       Qiyana        Varus  TahmKench     0.0
# 2           Aatrox   Sejuani         Azir  MissFortune   Nautilus     1.0
# 3            Quinn      Olaf      Orianna  MissFortune      Leona     0.0
# 4         Renekton     Elise       Velkoz        Varus      Braum     0.0
# ...            ...       ...          ...          ...        ...     ...
# 98452  Mordekaiser    LeeSin          Zed  MissFortune      Senna     0.0
# 98459       Soraka      Olaf         Fizz       Lucian      Senna     1.0
# 98462        Garen      Ekko      Camille        Yasuo     Thresh     0.0
# 98463      Camille   Taliyah        Talon  MissFortune   Nautilus     0.0
# 98468       Irelia      Olaf       Rumble      Kalista       Bard     1.0
#
# [40432 rows x 11 columns]

# %% [markdown]
# ### Unique Blue Teams

# %%
bluet = df[['bluetop','bluejungle','bluemid','blueadc','bluesupport']]
bluet

redt = df[['redtop','redjungle','redmid','redadc','redsupport']]
redt = redt.rename(columns={'redtop': 'bluetop', 'redjungle': 'bluejungle','redmid':'bluemid','redadc':'blueadc','redsupport':'bluesupport'})
allt = redt.append(bluet)
allt.groupby(['bluetop','bluejungle','bluemid','blueadc','bluesupport']).ngroups
allt
# Out:
#         bluetop bluejungle      bluemid      blueadc bluesupport
# 0        Aatrox     Gragas  Mordekaiser        Xayah       Rakan
# 1        Aatrox      Elise       Qiyana        Varus   TahmKench
# 2        Aatrox    Sejuani         Azir  MissFortune    Nautilus
# 3         Quinn       Olaf      Orianna  MissFortune       Leona
# 4      Renekton      Elise       Velkoz        Varus       Braum
# ...         ...        ...          ...          ...         ...
# 98452    Darius   JarvanIV     Katarina     Vladimir       Yuumi
# 98459      Sett     RekSai     Katarina        Xayah        Pyke
# 98462     Garen     LeeSin      Leblanc     Aphelios        Bard
# 98463  Kassadin     LeeSin      Leblanc       Ezreal       Leona
# 98468    Soraka   JarvanIV       Qiyana  MissFortune        Pyke
#
# [80864 rows x 5 columns]

# %% [markdown]
# ### Unique Red Teams

# %%
df.groupby(['redtop','redjungle','redmid','redadc','redsupport']).ngroups
# Out:
# 39901

# %%
df.groupby(['redtop','redjungle','redmid','redadc','redsupport']).ngroups
# Out:
# 39901

# %% [markdown]
# ### Unique Champions

# %%
topb = df['bluetop']
topr = df['redtop']
midb = df['bluemid']
midr = df['redmid']
jngb = df['bluejungle']
jngr = df['redjungle']
adcb = df['blueadc']
adcr = df['redadc']
supb = df['bluesupport']
supr = df['redsupport']
uni = df['redtop'].append(topb)
uni = uni.append(midb)
uni = uni.append(midr)
uni = uni.append(jngb)
uni = uni.append(jngr)
uni = uni.append(adcb)
uni = uni.append(adcr)
uni = uni.append(supb)
uni = uni.append(supr)
uni.nunique()
uni = uni.drop_duplicates()
uni
# Out:
# 0          Aatrox
# 3           Quinn
# 4        Renekton
# 5        Vladimir
# 7          Irelia
#            ...
# 70858        Zyra
# 72171      Xerath
# 79074       Yuumi
# 92712      RekSai
# 41894       Braum
# Length: 149, dtype: object

# %% [markdown]
# ### Win Rate by Champion

# %%
df
# Out:
#            bluetop bluejungle      bluemid      blueadc bluesupport  \
# 0           Rumble      Elise       Qiyana  MissFortune    Nautilus
# 1            Jayce   JarvanIV      Orianna  MissFortune    Nautilus
# 2         Renekton     RekSai  Mordekaiser        Xayah       Rakan
# 3         Pantheon      Elise     Nautilus        Xayah       Rakan
# 4      Mordekaiser   JarvanIV         Ryze        Xayah       Rakan
# ...            ...        ...          ...          ...         ...
# 98452       Darius   JarvanIV     Katarina     Vladimir       Yuumi
# 98459         Sett     RekSai     Katarina        Xayah        Pyke
# 98462        Garen     LeeSin      Leblanc     Aphelios        Bard
# 98463     Kassadin     LeeSin      Leblanc       Ezreal       Leona
# 98468       Soraka   JarvanIV       Qiyana  MissFortune        Pyke
#
#             redtop redjungle       redmid       redadc redsupport  result
# 0           Aatrox    Gragas  Mordekaiser        Xayah      Rakan     1.0
# 1           Aatrox     Elise       Qiyana        Varus  TahmKench     0.0
# 2           Aatrox   Sejuani         Azir  MissFortune   Nautilus     1.0
# 3            Quinn      Olaf      Orianna  MissFortune      Leona     0.0
# 4         Renekton     Elise       Velkoz        Varus      Braum     0.0
# ...            ...       ...          ...          ...        ...     ...
# 98452  Mordekaiser    LeeSin          Zed  MissFortune      Senna     0.0
# 98459       Soraka      Olaf         Fizz       Lucian      Senna     1.0
# 98462        Garen      Ekko      Camille        Yasuo     Thresh     0.0
# 98463      Camille   Taliyah        Talon  MissFortune   Nautilus     0.0
# 98468       Irelia      Olaf       Rumble      Kalista       Bard     1.0
#
# [40432 rows x 11 columns]

# %%
bluewins = df.query('result == 1 & (bluetop == "Rumble" | bluejungle == "Rumble" | bluemid == "Rumble" | blueadc == "Rumble" | bluesupport == "Rumble")').count()

# %%
redwins = df.query('result == 0 & (redtop == "Rumble" | redjungle == "Rumble" | redmid == "Rumble" | redadc == "Rumble" | redsupport == "Rumble")').count()

# %%
bluelosses = df.query('result == 0 & (bluetop == "Rumble" | bluejungle == "Rumble" | bluemid == "Rumble" | blueadc == "Rumble" | bluesupport == "Rumble")').count()

# %%
redlosses = df.query('result == 1 & (redtop == "Rumble" | redjungle == "Rumble" | redmid == "Rumble" | redadc == "Rumble" | redsupport == "Rumble")').count()

# %%
winrate = (bluewins+redwins)/(bluelosses+redlosses)

# %%
champs = []
winrates = []
totalplayed = []
for item in uni:
    champs.append(item)
    bluewins = df.query('result == 1 & (bluetop == "'+item+'" | bluejungle == "'+item+'" | bluemid == "'+item+'" | blueadc == "'+item+'" | bluesupport == "'+item+'")').count()
    redwins = df.query('result == 0 & (redtop == "'+item+'" | redjungle == "'+item+'" | redmid == "'+item+'" | redadc == "'+item+'" | redsupport == "'+item+'")').count()
    bluelosses = df.query('result == 0 & (bluetop == "'+item+'" | bluejungle == "'+item+'" | bluemid == "'+item+'" | blueadc == "'+item+'" | bluesupport == "'+item+'")').count()
    redlosses = df.query('result == 1 & (redtop == "'+item+'" | redjungle == "'+item+'" | redmid == "'+item+'" | redadc == "'+item+'" | redsupport == "'+item+'")').count()
    winrate = (bluewins+redwins)/(bluelosses+redlosses+bluewins+redwins)[0]
    winrates.append(winrate[0])
    totalplayed.append((bluelosses+redlosses+bluewins+redwins)[0])
    
print(winrates, totalplayed)
# Out:
# [0.4785581106277191, 0.5154929577464789, 0.49609862671660426, 0.52530199151159, 0.4595871238628412, 0.5028121484814398, 0.4986449864498645, 0.5, 0.4922784509384652, 0.5006310475389146, 0.512221618685497, 0.47765141496958474, 0.5223710458820177, 0.5144948755490483, 0.4828767123287671, 0.5096153846153846, 0.5003872966692486, 0.5114422565194252, 0.5150442477876106, 0.5033557046979866, 0.5285350781533987, 0.4998401704848162, 0.49654491609081935, 0.5055350553505535, 0.5055702917771884, 0.4904361132364193, 0.47395517867958814, 0.49077868852459017, 0.4672566371681416, 0.48385353330631, 0.48693778615674654, 0.4964493221433183, 0.49295774647887325, 0.5116586009678838, 0.4829700272479564, 0.4762924441725298, 0.5095513105286539, 0.46944151738672285, 0.5189718482252142, 0.49458483754512633, 0.49130434782608695, 0.48633879781420764, 0.48269581056466304, 0.5341426403641881, 0.48261474269819193, 0.4953560371517028, 0.49501246882793015, 0.44612068965517243, 0.5201361315938741, 0.5036344755970924, 0.5239294710327456, 0.4992134242265338, 0.5023832221163013, 0.5352260778128286, 0.518450184501845, 0.4962802975761939, 0.502426006792819, 0.5127255900046275, 0.5173501577287066, 0.5343803056027164, 0.5031784841075795, 0.4944944944944945, 0.5143592522351667, 0.47908232118758437, 0.4536082474226804, 0.4819277108433735, 0.514959202175884, 0.49747541854903005, 0.44516129032258067, 0.4911504424778761, 0.4994652406417112, 0.5116254379445802, 0.5183887915936952, 0.5347852389594676, 0.5199435227673844, 0.5256609642301711, 0.5063593004769475, 0.501331304678585, 0.5174060248285441, 0.5201149425287356, 0.47162162162162163, 0.5314009661835749, 0.5039775386055217, 0.49572649572649574, 0.48993585489935854, 0.47586980920314254, 0.5083415112855741, 0.5226824457593688, 0.4602346805736636, 0.47388932190179267, 0.49046461026494304, 0.4927854454203262, 0.5161101347393088, 0.45695364238410596, 0.5263784212614042, 0.4708612686952037, 0.5049833887043189, 0.5057573073516386, 0.5275435637998875, 0.5229157573112178, 0.489202657807309, 0.49745042492917846, 0.5011261261261262, 0.55404953145917, 0.49576059850374066, 0.495993524888709, 0.47296991630852747, 0.4768211920529801, 0.532686630113876, 0.5107304993809327, 0.5227164036346246, 0.5299145299145299, 0.48635235732009924, 0.5187680461982676, 0.5095846645367412, 0.53, 0.49206349206349204, 0.502903600464576, 0.5087507543753772, 0.48539857932123126, 0.5039370078740157, 0.5097402597402597, 0.49377005852369266, 0.5194444444444445, 0.48154657293497366, 0.5, 0.4985302763080541, 0.4956768347513315, 0.49650877524061143, 0.4845752254390128, 0.508148631029987, 0.4742014742014742, 0.4553191489361702, 0.5060422960725075, 0.5063039150630392, 0.5065610859728507, 0.48410041841004187, 0.45689655172413796, 0.4795244385733157, 0.49942889777270133, 0.5007363770250368, 0.486404833836858, 0.503785271851342, 0.47138713080168776, 0.4771689497716895, 0.4378947368421053, 0.4926936862420733, 0.5104740904079382, 0.4913169319826339] [6436, 710, 6408, 3063, 5716, 889, 5535, 2478, 4209, 2377, 1841, 3781, 3509, 3415, 292, 416, 2582, 1879, 565, 4917, 2751, 9385, 2026, 2710, 1885, 1307, 3302, 976, 565, 7401, 3713, 1549, 213, 2273, 8808, 3269, 2251, 1898, 4085, 2493, 920, 549, 549, 659, 719, 969, 1604, 464, 1763, 963, 2382, 5721, 2098, 1902, 1084, 4167, 4122, 4322, 634, 2356, 2045, 1998, 7382, 741, 582, 996, 1103, 3763, 155, 904, 935, 9419, 571, 1653, 2833, 643, 1258, 7887, 11519, 348, 740, 207, 2137, 585, 4521, 1782, 2038, 2535, 1534, 2566, 7813, 3188, 3414, 151, 2521, 3878, 903, 2258, 3558, 2291, 1204, 3530, 888, 5976, 2005, 12355, 4421, 755, 2371, 4846, 2091, 351, 403, 1039, 626, 500, 378, 861, 4971, 1267, 6985, 308, 10594, 720, 2276, 568, 1701, 14457, 5299, 2107, 3068, 814, 235, 662, 1507, 4420, 2390, 232, 757, 3502, 679, 331, 1453, 7584, 438, 475, 3627, 6349, 2764]

# %%
ch_wr_gp = (champs, winrates, totalplayed)
d = {'champ': champs, 'winrate': winrates, 'totalplayed':totalplayed}
new = pd.DataFrame(data=d)
new = new.sort_values('totalplayed')

# %%
ind = np.arange(len(new['champ']))  # the x locations for the groups
width = .4  # the width of the bars

plt.figure(figsize=(25,45))
plt.barh(ind, new['totalplayed'], width,
                color='violet', label='Games Played')

# Add some text for labels, title and custom x-axis tick labels, etc.
plt.ylabel('Champion', size=20)
plt.xlabel('Games Played', size=20)
plt.title('Total Games Played By Champion & Winrate by Champion', size=20)
plt.yticks(ind, new['champ'])

for i, (p, pr) in enumerate(zip(new["winrate"], new["totalplayed"])):
    plt.text(s=('%.0f' % (p*100))+'%', x=(pr+20), y=i, color="black", verticalalignment="center", size=13)
    #plt.text(s=str(round(pr,0))+"%", x=pr-5, y=i, color="black",
             #verticalalignment="center", horizontalalignment="left", size=10)

plt.show()

# %% [markdown]
# ### One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df = df.reset_index()
df = df.drop(axis=1, labels=['index'])
df
# Out:
#            bluetop bluejungle      bluemid      blueadc bluesupport  \
# 0           Rumble      Elise       Qiyana  MissFortune    Nautilus
# 1            Jayce   JarvanIV      Orianna  MissFortune    Nautilus
# 2         Renekton     RekSai  Mordekaiser        Xayah       Rakan
# 3         Pantheon      Elise     Nautilus        Xayah       Rakan
# 4      Mordekaiser   JarvanIV         Ryze        Xayah       Rakan
# ...            ...        ...          ...          ...         ...
# 40427       Darius   JarvanIV     Katarina     Vladimir       Yuumi
# 40428         Sett     RekSai     Katarina        Xayah        Pyke
# 40429        Garen     LeeSin      Leblanc     Aphelios        Bard
# 40430     Kassadin     LeeSin      Leblanc       Ezreal       Leona
# 40431       Soraka   JarvanIV       Qiyana  MissFortune        Pyke
#
#             redtop redjungle       redmid       redadc redsupport  result
# 0           Aatrox    Gragas  Mordekaiser        Xayah      Rakan     1.0
# 1           Aatrox     Elise       Qiyana        Varus  TahmKench     0.0
# 2           Aatrox   Sejuani         Azir  MissFortune   Nautilus     1.0
# 3            Quinn      Olaf      Orianna  MissFortune      Leona     0.0
# 4         Renekton     Elise       Velkoz        Varus      Braum     0.0
# ...            ...       ...          ...          ...        ...     ...
# 40427  Mordekaiser    LeeSin          Zed  MissFortune      Senna     0.0
# 40428       Soraka      Olaf         Fizz       Lucian      Senna     1.0
# 40429        Garen      Ekko      Camille        Yasuo     Thresh     0.0
# 40430      Camille   Taliyah        Talon  MissFortune   Nautilus     0.0
# 40431       Irelia      Olaf       Rumble      Kalista       Bard     1.0
#
# [40432 rows x 11 columns]

# %%
import tensorflow as tf
num_champions=150
champs_ = []
dic = {}
j=1
for col in df:
    if col != 'result':
        print(col)
        for i in range(len(df['bluetop'])):
            if(df[col][i] not in champs_):
                champs_.append(df[col][i])
                dic[df[col][i]] = j
                j = j + 1
                #print(df[col][i], j)
            

champs_.pop()
champs_.pop()
print(champs_)
# Out:
# bluetop
# bluejungle
# bluemid
# blueadc
# bluesupport
# redtop
# redjungle
# redmid
# redadc
# redsupport
# ['Rumble', 'Jayce', 'Renekton', 'Pantheon', 'Mordekaiser', 'Kennen', 'Camille', 'Aatrox', 'Ornn', 'Akali', 'Leblanc', 'Fiora', 'Sett', 'Gangplank', 'Vladimir', 'Irelia', 'Malphite', 'Swain', 'Gnar', 'Lucian', 'Sion', 'Poppy', 'Hecarim', 'Soraka', 'Kayle', 'Illaoi', 'Shen', 'Kled', 'Urgot', 'Chogath', 'Viktor', 'Sylas', 'Tristana', 'Sona', 'Quinn', 'Cassiopeia', 'Singed', 'Gragas', 'Olaf', 'Ryze', 'Darius', 'Zac', 'Maokai', 'Yorick', 'Karma', 'Nocturne', 'Yasuo', 'Kalista', 'Qiyana', 'Neeko', 'MonkeyKing', 'JarvanIV', 'Bard', 'Graves', 'Syndra', 'Tryndamere', 'Vayne', 'Zilean', 'Zoe', 'LeeSin', 'Jax', 'Riven', 'Nautilus', 'Janna', 'Fiddlesticks', 'Volibear', 'Shyvana', 'Rengar', 'Galio', 'DrMundo', 'Lillia', 'Lulu', 'Skarner', 'Nasus', 'Garen', 'Heimerdinger', 'Lissandra', 'TwistedFate', 'Kassadin', 'Ekko', 'Aphelios', 'Karthus', 'Senna', 'Nidalee', 'Teemo', 'Taric', 'Talon', 'Warwick', 'Trundle', 'Fizz', 'Rammus', 'Corki', 'Shaco', 'Ahri', 'Khazix', 'Draven', 'Katarina', 'Diana', 'Pyke', 'Malzahar', 'Sejuani', 'Orianna', 'XinZhao', 'MasterYi', 'Vi', 'Kayn', 'Ziggs', 'Zed', 'Zyra', 'Annie', 'Kaisa', 'Azir', 'Anivia', 'RekSai', 'Sivir', 'Elise', 'Twitch', 'MissFortune', 'Morgana', 'Alistar', 'Xerath', 'Veigar', 'Kindred', 'TahmKench', 'Caitlyn', 'Udyr', 'Nunu', 'Taliyah', 'Velkoz', 'Thresh', 'Ezreal', 'Xayah', 'Lux', 'Leona', 'Rakan', 'Amumu', 'Jhin', 'AurelionSol', 'Ashe', 'Blitzcrank', 'Jinx', 'Brand', 'Yuumi', 'Varus', 'Ivern', 'Evelynn', 'KogMaw']

# %%
dic
# Out:
# {'Rumble': 1,
#  'Jayce': 2,
#  'Renekton': 3,
#  'Pantheon': 4,
#  'Mordekaiser': 5,
#  'Kennen': 6,
#  'Camille': 7,
#  'Aatrox': 8,
#  'Ornn': 9,
#  'Akali': 10,
#  'Leblanc': 11,
#  'Fiora': 12,
#  'Sett': 13,
#  'Gangplank': 14,
#  'Vladimir': 15,
#  'Irelia': 16,
#  'Malphite': 17,
#  'Swain': 18,
#  'Gnar': 19,
#  'Lucian': 20,
#  'Sion': 21,
#  'Poppy': 22,
#  'Hecarim': 23,
#  'Soraka': 24,
#  'Kayle': 25,
#  'Illaoi': 26,
#  'Shen': 27,
#  'Kled': 28,
#  'Urgot': 29,
#  'Chogath': 30,
#  'Viktor': 31,
#  'Sylas': 32,
#  'Tristana': 33,
#  'Sona': 34,
#  'Quinn': 35,
#  'Cassiopeia': 36,
#  'Singed': 37,
#  'Gragas': 38,
#  'Olaf': 39,
#  'Ryze': 40,
#  'Darius': 41,
#  'Zac': 42,
#  'Maokai': 43,
#  'Yorick': 44,
#  'Karma': 45,
#  'Nocturne': 46,
#  'Yasuo': 47,
#  'Kalista': 48,
#  'Qiyana': 49,
#  'Neeko': 50,
#  'MonkeyKing': 51,
#  'JarvanIV': 52,
#  'Bard': 53,
#  'Graves': 54,
#  'Syndra': 55,
#  'Tryndamere': 56,
#  'Vayne': 57,
#  'Zilean': 58,
#  'Zoe': 59,
#  'LeeSin': 60,
#  'Jax': 61,
#  'Riven': 62,
#  'Nautilus': 63,
#  'Janna': 64,
#  'Fiddlesticks': 65,
#  'Volibear': 66,
#  'Shyvana': 67,
#  'Rengar': 68,
#  'Galio': 69,
#  'DrMundo': 70,
#  'Lillia': 71,
#  'Lulu': 72,
#  'Skarner': 73,
#  'Nasus': 74,
#  'Garen': 75,
#  'Heimerdinger': 76,
#  'Lissandra': 77,
#  'TwistedFate': 78,
#  'Kassadin': 79,
#  'Ekko': 80,
#  'Aphelios': 81,
#  'Karthus': 82,
#  'Senna': 83,
#  'Nidalee': 84,
#  'Teemo': 85,
#  'Taric': 86,
#  'Talon': 87,
#  'Warwick': 88,
#  'Trundle': 89,
#  'Fizz': 90,
#  'Rammus': 91,
#  'Corki': 92,
#  'Shaco': 93,
#  'Ahri': 94,
#  'Khazix': 95,
#  'Draven': 96,
#  'Katarina': 97,
#  'Diana': 98,
#  'Pyke': 99,
#  'Malzahar': 100,
#  'Sejuani': 101,
#  'Orianna': 102,
#  'XinZhao': 103,
#  'MasterYi': 104,
#  'Vi': 105,
#  'Kayn': 106,
#  'Ziggs': 107,
#  'Zed': 108,
#  'Zyra': 109,
#  'Annie': 110,
#  'Kaisa': 111,
#  'Azir': 112,
#  'Anivia': 113,
#  'RekSai': 114,
#  'Sivir': 115,
#  'Elise': 116,
#  'Twitch': 117,
#  'MissFortune': 118,
#  'Morgana': 119,
#  'Alistar': 120,
#  'Xerath': 121,
#  'Veigar': 122,
#  'Kindred': 123,
#  'TahmKench': 124,
#  'Caitlyn': 125,
#  'Udyr': 126,
#  'Nunu': 127,
#  'Taliyah': 128,
#  'Velkoz': 129,
#  'Thresh': 130,
#  'Ezreal': 131,
#  'Xayah': 132,
#  'Lux': 133,
#  'Leona': 134,
#  'Rakan': 135,
#  'Amumu': 136,
#  'Jhin': 137,
#  'AurelionSol': 138,
#  'Ashe': 139,
#  'Blitzcrank': 140,
#  'Jinx': 141,
#  'Brand': 142,
#  'Yuumi': 143,
#  'Varus': 144,
#  'Ivern': 145,
#  'Evelynn': 146,
#  'KogMaw': 147,
#  'Braum': 148,
#  'Nami': 149}

# %%
for col in df:
    if col != 'result':
        for i in range(len(df['bluetop'])):
            #print(df[col][i])
            df.at[i, col] = dic[df[col][i]]
            
df
# Out:
#       bluetop bluejungle bluemid blueadc bluesupport redtop redjungle redmid  \
# 0           1        116      49     118          63      8        38      5
# 1           2         52     102     118          63      8       116     49
# 2           3        114       5     132         135      8       101    112
# 3           4        116      63     132         135     35        39    102
# 4           5         52      40     132         135      3       116    129
# ...       ...        ...     ...     ...         ...    ...       ...    ...
# 40427      41         52      97      15         143      5        60    108
# 40428      13        114      97     132          99     24        39     90
# 40429      75         60      11      81          53     75        80      7
# 40430      79         60      11     131         134      7       128     87
# 40431      24         52      49     118          99     16        39      1
#
#       redadc redsupport  result
# 0        132        135     1.0
# 1        144        124     0.0
# 2        118         63     1.0
# 3        118        134     0.0
# 4        144        148     0.0
# ...      ...        ...     ...
# 40427    118         83     0.0
# 40428     20         83     1.0
# 40429     47        130     0.0
# 40430    118         63     0.0
# 40431     48         53     1.0
#
# [40432 rows x 11 columns]

# %%
X = df.copy()

# %% [markdown]
# ### Randomize SHuffle

# %%
X=X.sample(frac=1)
X
# Out:
#       bluetop bluejungle bluemid blueadc bluesupport redtop redjungle redmid  \
# 8385        5        116      49     144         124     32        60      6
# 15732      12         51      92     137          45     32        54    131
# 31548      68        116      90     124          83     43        65     87
# 32786       1         84       7     118         124      4       116     49
# 28617       8         95      98     131         130     22        82    108
# ...       ...        ...     ...     ...         ...    ...       ...    ...
# 27474      89         65      16      57         148     47        84      3
# 1092        8        116     144     118         124      3        60     59
# 33020       2         95      98     131         133     15        60     94
# 15190      12         54       4      48          13     28        80     20
# 5602       19         84     112     125          53      3        71     59
#
#       redadc redsupport  result
# 8385     118        143     0.0
# 15732    144        133     1.0
# 31548    139         27     0.0
# 32786    144         99     0.0
# 28617    111        120     1.0
# ...      ...        ...     ...
# 27474    118         53     0.0
# 1092     141        130     1.0
# 33020    111        143     0.0
# 15190    118         53     1.0
# 5602     139         63     0.0
#
# [40432 rows x 11 columns]

# %%
len(X.columns)
# Out:
# 11

# %%
X = X.tail(300)

# %% [markdown]
# ### Sklearn

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

results = X['result']
X = X.drop(axis=1,labels=['result'])

# %%
X
# Out:
#       bluetop bluejungle bluemid blueadc bluesupport redtop redjungle redmid  \
# 24256       5         95      55     131         142      9        89     31
# 37933       8         20      97     107         135     85       116      7
# 30604      13         80      87     141         119     32        52     49
# 25985      16         80      99      48         130     74        88     10
# 26333      68         32      11     132         135     25        42     46
# ...       ...        ...     ...     ...         ...    ...       ...    ...
# 27474      89         65      16      57         148     47        84      3
# 1092        8        116     144     118         124      3        60     59
# 33020       2         95      98     131         133     15        60     94
# 15190      12         54       4      48          13     28        80     20
# 5602       19         84     112     125          53      3        71     59
#
#       redadc redsupport
# 24256    137         83
# 37933     81        149
# 30604    111         63
# 25985    144         83
# 26333    131        133
# ...      ...        ...
# 27474    118         53
# 1092     141        130
# 33020    111        143
# 15190    118         53
# 5602     139         63
#
# [300 rows x 10 columns]

# %% [markdown]
# ### Tensorflow

# %%
import tensorflow as tf
import sklearn

# %%
r = random.randint(1, 100)

input_array = np.asarray(X.values).astype(np.float32)
target = np.asarray(results.values)

X_train, X_test, y_train, y_test = train_test_split(input_array, target, random_state=r)

# %%
def fit_model():
    
    model = tf.keras.models.Sequential([tf.keras.layers.Embedding(150, 10, input_length=10),
                                   tf.keras.layers.Flatten(),
                                   tf.keras.layers.Dense(300, activation='tanh', 
                                                         kernel_initializer='uniform', 
                                                         bias_initializer='zeros'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(300, activation='tanh', 
                                                         kernel_initializer='uniform', 
                                                         bias_initializer='zeros'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(300, activation='tanh', 
                                                         kernel_initializer='uniform', 
                                                         bias_initializer='zeros'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(300, activation='tanh', 
                                                         kernel_initializer='uniform', 
                                                         bias_initializer='zeros'),
                                    tf.keras.layers.Dropout(0.5),
                                    tf.keras.layers.Dense(1, activation='sigmoid')
                                   ])
    model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=5, validation_split=.1)
    return model

# %%
# fit all models
n_members = 10
members = [fit_model() for _ in range(n_members)]
# Out:
# Epoch 1/5
# 7/7 [==============================] - 0s 29ms/step - loss: 0.6921 - accuracy: 0.5396 - val_loss: 0.7083 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6833 - accuracy: 0.5495 - val_loss: 0.7279 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6735 - accuracy: 0.5545 - val_loss: 0.7254 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6214 - accuracy: 0.6535 - val_loss: 0.7508 - val_accuracy: 0.4348
# Epoch 5/5
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4635 - accuracy: 0.7822 - val_loss: 0.9946 - val_accuracy: 0.5652
# Epoch 1/5
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6948 - accuracy: 0.5248 - val_loss: 0.7104 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6889 - accuracy: 0.5495 - val_loss: 0.7052 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6839 - accuracy: 0.5495 - val_loss: 0.7322 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6585 - accuracy: 0.5941 - val_loss: 0.7080 - val_accuracy: 0.3913
# Epoch 5/5
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5613 - accuracy: 0.7673 - val_loss: 0.8200 - val_accuracy: 0.4783
# Epoch 1/5
# 7/7 [==============================] - 0s 31ms/step - loss: 0.6931 - accuracy: 0.5099 - val_loss: 0.7058 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6873 - accuracy: 0.5495 - val_loss: 0.7221 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6864 - accuracy: 0.5495 - val_loss: 0.7380 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6676 - accuracy: 0.5495 - val_loss: 0.7313 - val_accuracy: 0.3478
# Epoch 5/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.7030 - val_loss: 0.7593 - val_accuracy: 0.5217
# Epoch 1/5
# 7/7 [==============================] - 0s 28ms/step - loss: 0.6939 - accuracy: 0.5248 - val_loss: 0.7067 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6880 - accuracy: 0.5495 - val_loss: 0.7110 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6825 - accuracy: 0.5495 - val_loss: 0.7300 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6601 - accuracy: 0.5594 - val_loss: 0.7648 - val_accuracy: 0.3478
# Epoch 5/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5746 - accuracy: 0.7624 - val_loss: 0.9536 - val_accuracy: 0.4348
# Epoch 1/5
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6927 - accuracy: 0.5495 - val_loss: 0.7119 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6868 - accuracy: 0.5495 - val_loss: 0.7265 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6786 - accuracy: 0.5495 - val_loss: 0.7276 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6413 - accuracy: 0.6931 - val_loss: 0.7224 - val_accuracy: 0.4783
# Epoch 5/5
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5326 - accuracy: 0.7475 - val_loss: 1.1286 - val_accuracy: 0.4348
# Epoch 1/5
# 7/7 [==============================] - 0s 26ms/step - loss: 0.6915 - accuracy: 0.5248 - val_loss: 0.7096 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6866 - accuracy: 0.5495 - val_loss: 0.7199 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6823 - accuracy: 0.5495 - val_loss: 0.7194 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6653 - accuracy: 0.5545 - val_loss: 0.7473 - val_accuracy: 0.3913
# Epoch 5/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.5701 - accuracy: 0.6980 - val_loss: 0.8541 - val_accuracy: 0.5217
# Epoch 1/5
# 7/7 [==============================] - 0s 25ms/step - loss: 0.6916 - accuracy: 0.5198 - val_loss: 0.7078 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6874 - accuracy: 0.5495 - val_loss: 0.7179 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6827 - accuracy: 0.5495 - val_loss: 0.7336 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6543 - accuracy: 0.5990 - val_loss: 0.6922 - val_accuracy: 0.4348
# Epoch 5/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5785 - accuracy: 0.7426 - val_loss: 0.7836 - val_accuracy: 0.4348
# Epoch 1/5
# 7/7 [==============================] - 0s 36ms/step - loss: 0.6923 - accuracy: 0.5198 - val_loss: 0.7044 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6903 - accuracy: 0.5495 - val_loss: 0.7220 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6755 - accuracy: 0.5495 - val_loss: 0.7067 - val_accuracy: 0.3478
# Epoch 4/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6478 - accuracy: 0.6881 - val_loss: 0.6818 - val_accuracy: 0.5217
# Epoch 5/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5118 - accuracy: 0.8069 - val_loss: 0.8454 - val_accuracy: 0.5652
# Epoch 1/5
# 7/7 [==============================] - 0s 27ms/step - loss: 0.6928 - accuracy: 0.5198 - val_loss: 0.7058 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6888 - accuracy: 0.5495 - val_loss: 0.7311 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6811 - accuracy: 0.5495 - val_loss: 0.7298 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6640 - accuracy: 0.5941 - val_loss: 0.7696 - val_accuracy: 0.3478
# Epoch 5/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.5717 - accuracy: 0.7030 - val_loss: 0.9015 - val_accuracy: 0.4783
# Epoch 1/5
# 7/7 [==============================] - 0s 23ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.7030 - val_accuracy: 0.3913
# Epoch 2/5
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6880 - accuracy: 0.5495 - val_loss: 0.7328 - val_accuracy: 0.3913
# Epoch 3/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6873 - accuracy: 0.5495 - val_loss: 0.7398 - val_accuracy: 0.3913
# Epoch 4/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6644 - accuracy: 0.5743 - val_loss: 0.7230 - val_accuracy: 0.3913
# Epoch 5/5
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6166 - accuracy: 0.7030 - val_loss: 0.7863 - val_accuracy: 0.3913

# %%
# make an ensemble prediction for multi-class classification
def ensemble_predictions(members, testX):
    # make predictions
    yhats = [model.predict(testX) for model in members]
    yhats = np.array(yhats)
    # sum across ensemble members
    summed = np.sum(yhats, axis=0)
    # argmax across classes
    result = np.round(summed/len(members))#np.argmax(summed, axis=1)
    #print(result)
    return result

# %%
# evaluate a specific number of members in an ensemble
def evaluate_n_members(members, n_members, testX, testy):
    # select a subset of members
    subset = members[:n_members]
    # make prediction
    yhat = ensemble_predictions(subset, testX)
    # calculate accuracy
    return sklearn.metrics.accuracy_score(testy, yhat)

# %%
# evaluate different numbers of ensembles on hold out set
single_scores, ensemble_scores = list(), list()
for i in range(1, len(members)+1):
    # evaluate model with i members
    ensemble_score = evaluate_n_members(members, i, X_test, y_test)
    # evaluate the i'th model standalone
    #testy_enc = tf.keras.utils.to_categorical(y_test)
    _, single_score = members[i-1].evaluate(X_test, y_test, verbose=0)
    # summarize this step
    print('> %d: single=%.3f, ensemble=%.3f' % (i, single_score, ensemble_score))
    ensemble_scores.append(ensemble_score)
    single_scores.append(single_score)
# summarize average accuracy of a single final model
print('Accuracy %.3f (%.3f)' % (np.mean(single_scores), np.std(single_scores)))
# Out:
# > 1: single=0.507, ensemble=0.507
# > 2: single=0.600, ensemble=0.533
# > 3: single=0.547, ensemble=0.533
# > 4: single=0.600, ensemble=0.520
# > 5: single=0.560, ensemble=0.547
# > 6: single=0.547, ensemble=0.533
# > 7: single=0.520, ensemble=0.533
# > 8: single=0.427, ensemble=0.493
# > 9: single=0.453, ensemble=0.480
# > 10: single=0.547, ensemble=0.467
# Accuracy 0.531 (0.054)
